# %% [markdown]
# # Step 5 — Explore Collection Information

# %%
import pandas as pd

# Load dataset (ubah path sesuai lokasi file Anda)
file_path = r"C:\Users\Michael Marcel\OneDrive\Desktop\TA\Data\Dataset\student_lifestyle_100k.csv"

df = pd.read_csv(file_path)

df.head()
# Out:
#    Student_ID  Age  Gender   Department  CGPA  Sleep_Duration  Study_Hours  \
# 0        1001   22  Female      Science  3.50             7.3          3.3
# 1        1002   20    Male  Engineering  2.72             5.5          7.2
# 2        1003   20    Male      Medical  3.01             5.4          2.3
# 3        1004   21    Male  Engineering  3.63             8.1          2.0
# 4        1005   19    Male         Arts  3.14             6.8          2.6
#
#    Social_Media_Hours  Physical_Activity  Stress_Level  Depression
# 0                 3.4                114             5       False
# 1                 6.0                142             2       False
# 2                 1.8                137             3       False
# 3                 4.6                130             3       False
# 4                 4.3                  4             6       False

# %%
# Struktur dataset
print('Jumlah Baris & Kolom :', df.shape)

print("DAFTAR NAMA KOLOM")
print(df.columns)
# Out:
# Jumlah Baris & Kolom : (100000, 11)
# DAFTAR NAMA KOLOM
# Index(['Student_ID', 'Age', 'Gender', 'Department', 'CGPA', 'Sleep_Duration',
#        'Study_Hours', 'Social_Media_Hours', 'Physical_Activity',
#        'Stress_Level', 'Depression'],
#       dtype='str')

# %%
# Cek kolom tanggal (jika ada)
date_cols = df.select_dtypes(include=['datetime64']).columns

# %% [markdown]
# Dataset tidak memuat kolom bertipe tanggal atau waktu sehingga periode pengumpulan data tidak dapat diidentifikasi dan analisis berbasis temporal tidak dapat dilakukan.

# %% [markdown]
# ### Inferensi Sumber Data
#
# Dataset kemungkinan dikumpulkan melalui survei/kuesioner mahasiswa yang mencatat gaya hidup, akademik, dan kesehatan mental.

# %% [markdown]
# ### Potensi Bias
#
# - Self‑report bias
# - Sampling bias
# - Recall bias
# - Social desirability bias

# %%
# Cek Missing Values
missing = df.isnull().sum()

print(missing[missing > 0])
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Hasil menunjukkan tidak terdapat missing values pada seluruh variabel sehingga dataset memiliki tingkat kelengkapan data yang baik untuk analisis lanjutan. Dataset tidak menyediakan informasi lokasi atau wilayah responden
