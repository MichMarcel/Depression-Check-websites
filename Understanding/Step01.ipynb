# %% [markdown]
# ## STEP 1 — LOAD & VIEW DATASET

# %%
import pandas as pd

# %%
# Load dataset
file_path = "student_lifestyle_100k.csv"
df = pd.read_csv(r"C:\Users\Michael Marcel\OneDrive\Desktop\TA\Data\Dataset\student_lifestyle_100k.csv")

# %%
# Preview 5 baris pertama
print("5 BARIS PERTAMA DATASET")
print(df.head(10))
# Out:
# 5 BARIS PERTAMA DATASET
#    Student_ID  Age  Gender   Department  CGPA  Sleep_Duration  Study_Hours  \
# 0        1001   22  Female      Science  3.50             7.3          3.3
# 1        1002   20    Male  Engineering  2.72             5.5          7.2
# 2        1003   20    Male      Medical  3.01             5.4          2.3
# 3        1004   21    Male  Engineering  3.63             8.1          2.0
# 4        1005   19    Male         Arts  3.14             6.8          2.6
# 5        1006   22  Female      Medical  3.31             6.5          3.5
# 6        1007   18    Male      Science  2.14             4.4          4.0
# 7        1008   18    Male  Engineering  3.27             7.0          3.4
# 8        1009   21    Male     Business  2.71             4.8          8.6
# 9        1010   24    Male  Engineering  3.36             5.7          1.5
#
#    Social_Media_Hours  Physical_Activity  Stress_Level  Depression
# 0                 3.4                114             5       False
# 1                 6.0                142             2       False
# 2                 1.8                137             3       False
# 3                 4.6                130             3       False
# 4                 4.3                  4             6       False
# 5                 4.1                129             2       False
# 6                 3.1                 73             8        True
# 7                 7.6                 68             4       False
# 8                 0.3                 82             5       False
# 9                 3.7                 59             3       False

# %%
# Preview 5 baris terakhir
print("5 BARIS TERAKHIR DATASET")
print(df.tail())
# Out:
# 5 BARIS TERAKHIR DATASET
#        Student_ID  Age  Gender   Department  CGPA  Sleep_Duration  \
# 99995      100996   24  Female      Medical  2.02             7.0
# 99996      100997   24    Male         Arts  2.33             5.0
# 99997      100998   24  Female  Engineering  2.23             6.5
# 99998      100999   19    Male  Engineering  3.61             6.1
# 99999      101000   24  Female      Medical  2.10             7.9
#
#        Study_Hours  Social_Media_Hours  Physical_Activity  Stress_Level  \
# 99995          0.6                 1.4                 66             4
# 99996          3.6                 5.2                103             3
# 99997          5.8                 4.1                 61             5
# 99998          4.8                 4.9                116             4
# 99999          3.5                 4.0                 79             4
#
#        Depression
# 99995       False
# 99996       False
# 99997       False
# 99998       False
# 99999       False

# %%
# Menampilkan ukuran dataset
rows, cols = df.shape

print("UKURAN DATASET")
print(f"Jumlah Baris  : {rows}")
print(f"Jumlah Kolom : {cols}")
# Out:
# UKURAN DATASET
# Jumlah Baris  : 100000
# Jumlah Kolom : 11
